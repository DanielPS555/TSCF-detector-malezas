# %%
# !export PYTORCH_ROCM_ARCH="gfx1031"
# !export HIP_VISIBLE_DEVICES=0
# !export ROCM_PATH=/opt/rocm

# %%
from ultralytics import YOLO

# %%
model = YOLO('runs/detect/fine-tuning/last.pt')
model = model.to('cuda')
model.info()

model.tune(data='datasets/v5_solo_lolium/data.yaml', epochs=30, iterations=50, optimizer='AdamW', plots=True, save=True, val=True, cache=True, batch=16, project='runs/detect/fine-tuning',imgsz=640)

model.save('runs/detect/fine-tuning/last.pt')
# Out:
# YOLOv9c summary: 618 layers, 25530003 parameters, 0 gradients, 103.7 GFLOPs
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/fine-tuning/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.3.0+rocm6.0 CUDA:0 (AMD Radeon RX 6700 XT, 12272MiB)
# ...
