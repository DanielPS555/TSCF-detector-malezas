# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d_batch_nada = pd.read_csv('./yolov9c - PREENTRENADO - batch16 - DataAugmentation - v6_Allv13 - NO HP - 160 epocas/results.csv', index_col=0)
d_batch_HP = pd.read_csv('./yolov9c - PREENTRENADO - batch16 - DataAugmentation - v6_Allv13 - Con HP - 200 epocas/results.csv', index_col=0)
d_batch_freeze = pd.read_csv('./yolov9c - dataset v13 - SIN HP, SIN GAN - freeze/results.csv', index_col=0)
d_batch_HP_freeze = pd.read_csv('./yolov9c - dataset v13 - con HP, con GAN - freeze/results.csv', index_col=0)

# %%
df_maps50 = pd.DataFrame()

df_maps50['Sin congelamiento, Sin hiperparámetros encontrados'] = d_batch_nada['       metrics/mAP50(B)']
df_maps50['Sin congelamiento, Con hiperparámetros encontrados'] = d_batch_HP['       metrics/mAP50(B)']
df_maps50['Con congelamiento, Sin hiperparámetros encontrados'] = d_batch_freeze['       metrics/mAP50(B)']
df_maps50['Con congelamiento, Con hiperparámetros encontrados'] = d_batch_HP_freeze['       metrics/mAP50(B)']


df_maps50.plot( title= 'mAP50 | Rendimiento aplicando congelamiento e hiperparámetros encontrados', ylabel="mAP50", figsize=(20,10), )
# Out:
# <Axes: title={'center': 'mAP50 | Rendimiento aplicando congelamiento e hiperparámetros encontrados'}, xlabel='                  epoch', ylabel='mAP50'>

# %%
_, axes = plt.subplots(1,2) 

df_maps50_2 = pd.DataFrame()


df_maps50_2['No Congelamiento'] = d_batch16['       metrics/mAP50(B)']
df_maps50_2['Congelando primeras 10 capas'] = d_batch16_f['       metrics/mAP50(B)']


df_maps50_2.plot( title= 'mAP50 | Rendimiento al aplicar congelamiento', ylabel="mAP50", figsize=(20,10), ax=axes[0])


df_maps50_90_2 = pd.DataFrame()


df_maps50_90_2['Lote tamaño 16'] = d_batch16['    metrics/mAP50-95(B)']
df_maps50_90_2['Lote tamaño 16 con congelamiento'] = d_batch16_f['    metrics/mAP50-95(B)']

df_maps50_90_2.plot( title= 'mAP50-95 | Rendimiento al aplicar congelamiento', ylabel="mAP50-95", figsize=(20,10), ax=axes[1])
# Out:
# <Axes: title={'center': 'mAP50-95 | Rendimiento al aplicar congelamiento'}, xlabel='                  epoch', ylabel='mAP50-95'>
